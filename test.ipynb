# %%
import asyncio
from langchain_openai import ChatOpenAI
from langchain_core.callbacks import StreamingStdOutCallbackHandler # 也可以自定义回调
import os
def stream_response():
    chat = ChatOpenAI(
    api_key=os.getenv("DASHSCOPE_API_KEY"),
    base_url="https://dashscope.aliyuncs.com/compatible-mode/v1",
    model="qwen-plus",  # 此处以qwen-plus为例，您可按需更换模型名称。模型列表：https://help.aliyun.com/zh/model-studio/getting-started/models
    temperature=0,
        streaming=True) #  可以传入回调

    for chunk in chat.stream("给我讲一个关于太空旅行的长故事。"):
        print(chunk.content, end="", flush=True)



stream_response()
# Out:
# ### 太空旅行的奇迹：星际之桥
#
# 在遥远的未来，人类已经突破了地球的束缚，开始向宇宙深处探索。科技的进步让人类能够建造巨大的星际飞船，并通过一种名为“量子跃迁”的技术实现超光速旅行。然而，这种技术并非完美无缺，它需要消耗大量的能源，而且每次跃迁都伴随着未知的风险。
#
# #### 第一章：启程
#
# 故事发生在一个名为“曙光号”的星际飞船上。这艘船是人类历史上最先进的探险舰之一，由一群勇敢的科学家、工程师和宇航员组成。他们的目标是前往距离地球12光年外的一颗类地行星——阿尔法-7。根据探测器传回的数据，这颗行星可能拥有适合生命存在的环境。
#
# 主角是一位年轻的女工程师，名叫艾琳娜。她从小就对星空充满了向往，梦想着有一天能亲自踏上其他星球的土地。作为“曙光号”上的核心技术人员，她的任务是维护飞船的动力系统和跃迁引擎。
#
# 出发那天，整个地球都在欢送他们。人们聚集在发射场周围，目送着“曙光号”缓缓升空，消失在大气层之外。艾琳娜站在控制室里，透过舷窗望向渐行渐远的蓝色星球，心中既兴奋又忐忑。
#
# #### 第二章：意外与挑战
#
# 经过数月的平稳航行，“曙光号”终于接近了第一段跃迁点。然而，在执行跃迁程序时，意外发生了。由于未知的能量波动，飞船被抛离了预定轨道，进入了未知的星域。
#
# 当船员们从混乱中恢复过来时，他们发现自己正漂浮在一个陌生的星系中。这里没有熟悉的恒星，也没有任何已知的导航数据。更糟糕的是，跃迁引擎的核心部件受损，无法再次启动。
#
# 面对这一困境，团队必须迅速找到解决方案。艾琳娜带领维修小组日夜奋战，试图修复引擎。与此同时，天文学家们利用飞船上的望远镜扫描周围的星体，希望能发现一条新的航线返回原定目标。
#
# 在这个过程中，艾琳娜结识了一位性格开朗的飞行员马克。他总是用幽默的方式缓解大家的压力，同时也在飞行操作方面提供了关键帮助。两人逐渐建立了深厚的友谊，甚至萌生出超越同事关系的情感。
#
# #### 第三章：神秘的信号
#
# 就在众人努力寻找出路时，飞船接收到了一段奇怪的无线电信号。这段信号似乎来自某个遥远的星球，而且带有规律性的脉冲特征，显然不是自然现象。
#
# 船长决定派遣一艘小型探测器去调查信号来源。经过几天的飞行，探测器传回了令人震惊的画面：那是一片废墟般的城市遗迹！这些遗迹显示，曾经有一个高度发达的文明存在于那个星球上。
#
# 然而，这个文明却早已灭绝。从残留的技术痕迹来看，他们可能是因为过度依赖某种强大的能量源而导致自我毁灭。这一发现让所有人都陷入了沉思。如果人类不加节制地开发资源，是否也会走上同样的道路？
#
# #### 第四章：重生的机会
#
# 尽管遭遇挫折，但船员们并没有放弃希望。艾琳娜最终成功修复了跃迁引擎，但为了确保安全抵达阿尔法-7，他们还需要补充额外的能量。
#
# 幸运的是，在进一步探索中，他们发现了一个富含稀有矿物的小行星带。通过开采这些矿物，他们不仅解决了能量问题，还积累了宝贵的研究资料。
#
# 几个月后，“曙光号”终于完成了最后一次跃迁，顺利抵达阿尔法-7。当飞船穿过大气层，降落在这片陌生的土地上时，所有人都屏住了呼吸。映入眼帘的是广袤的绿色森林、清澈的湖泊以及蔚蓝的天空——这一切看起来竟如此熟悉，仿佛回到了家乡。
#
# #### 第五章：新家园的起点
#
# 阿尔法-7的确是一个充满潜力的世界。科学家们立即展开研究，确认这里的空气可以呼吸，土壤适合种植作物，水体也完全可用。这意味着，人类第一次真正找到了另一个可供居住的星球。
#
# 艾琳娜站在新世界的土地上，感受着微风拂过脸颊，内心充满了喜悦和敬畏。她知道，这只是人类迈向星辰大海的第一步。未来还有无数的未知等待着他们去探索。
#
# 而马克则轻轻握住她的手，低声说道：“无论接下来会发生什么，只要我们一起面对，就没有什么是不可能的。”
#
# 随着太阳缓缓升起，照亮了这片崭新的天地，“曙光号”的成员们开始了他们在新家园的生活。他们相信，这只是一个伟大旅程的开端，而人类的故事，将在浩瀚的宇宙中继续书写下去。
#
# ---
#
# 这是一个关于勇气、智慧和希望的故事。它提醒我们，即使面对再大的困难，只要团结一心，就能开辟通往未来的道路。或许某一天，我们真的会像艾琳娜和她的伙伴们一样，踏足那些遥远的星球，开启属于全人类的新篇章。
