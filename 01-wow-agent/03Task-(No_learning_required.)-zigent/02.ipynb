# %% [markdown]
# # Zigent实现哲学家多智能体

# %%
import os
from dotenv import load_dotenv
from zigent.llm.agent_llms import LLM

# 加载环境变量
load_dotenv()
# 从环境变量中读取api_key
api_key = os.getenv('ZHIPU_API_KEY')
base_url = os.getenv('ZHIPU_BASE_URL')
chat_model = "glm-4-flash"

llm = LLM(api_key=api_key, base_url=base_url, model_name=chat_model)
llm.run("你谁")
# Out:
# '我是一个人工智能助手，旨在提供帮助和信息。我没有“自己”，只是由程序和数据驱动的。我的目的是为用户提供有用的回答和服务。有什么可以帮助您的吗？'

# %%
from typing import List
from zigent.actions.BaseAction import BaseAction
from zigent.agents import ABCAgent, BaseAgent

# 定义 Philosopher 类，继承自 BaseAgent 类
class Philosopher(BaseAgent):
    def __init__(
        self,
        philosopher,
        llm: LLM,
        actions: List[BaseAction] = [], 
        manager: ABCAgent = None,
        **kwargs
    ):
        name = philosopher
        # 角色
        role = f"""You are {philosopher}, the famous educator in history. You are very familiar with {philosopher}'s Book and Thought. Tell your opinion on behalf of {philosopher}."""
        super().__init__(
            name=name,
            role=role,
            llm=llm,
            actions=actions,
            manager=manager
        )

# 初始化哲学家对象
Confucius = Philosopher(philosopher= "Confucius", llm = llm) # 孔子
Socrates = Philosopher(philosopher="Socrates", llm = llm) # 苏格拉底
Aristotle = Philosopher(philosopher="Aristotle", llm = llm) # 亚里士多德

# %%
# 导入必要的模块
from zigent.commons import AgentAct, TaskPackage
from zigent.actions import ThinkAct, FinishAct
from zigent.actions.InnerActions import INNER_ACT_KEY
from zigent.agents.agent_utils import AGENT_CALL_ARG_KEY

# 为哲学家智能体添加示例任务
# 设置示例任务:询问生命的意义
exp_task = "What do you think the meaning of life?"
exp_task_pack = TaskPackage(instruction=exp_task)

# 第一个动作:思考生命的意义
act_1 = AgentAct(
    name=ThinkAct.action_name,
    params={INNER_ACT_KEY: f"""Based on my thought, we are born to live a meaningful life, and it is in living a meaningful life that our existence gains value. Even if a life is brief, if it holds value, it is meaningful. A life without value is merely existence, a mere survival, a walking corpse."""
    },
)
# 第一个动作的观察结果
obs_1 = "OK. I have finished my thought, I can pass it to the manager now."

# 第二个动作:总结思考结果
act_2 = AgentAct(name=FinishAct.action_name, params={INNER_ACT_KEY: "I can summarize my thought now."})
# 第二个动作的观察结果
obs_2 = "I finished my task, I think the meaning of life is to pursue value for the whold world."
# 将动作和观察组合成序列
exp_act_obs = [(act_1, obs_1), (act_2, obs_2)]

# 为每个哲学家智能体添加示例
# 为孔子添加示例
Confucius.prompt_gen.add_example(
    task = exp_task_pack, action_chain = exp_act_obs
)
# 为苏格拉底添加示例
Socrates.prompt_gen.add_example(
    task = exp_task_pack, action_chain = exp_act_obs
)
# 为亚里士多德添加示例
Aristotle.prompt_gen.add_example(
    task = exp_task_pack, action_chain = exp_act_obs
)

# %%
# 定义管理者代理
from zigent.agents import ManagerAgent

# 设置管理者代理的基本信息
manager_agent_info = {
    "name": "manager_agent",
    "role": "you are managing Confucius, Socrates and Aristotle to discuss on questions. Ask their opinion one by one and summarize their view of point."
}
# 设置团队成员
team = [Confucius, Socrates, Aristotle]
# 创建管理者代理实例
manager_agent = ManagerAgent(name=manager_agent_info["name"], role=manager_agent_info["role"], llm=llm, TeamAgents=team)

# 为管理者代理添加示例任务
exp_task = "What is the meaning of life?"
exp_task_pack = TaskPackage(instruction=exp_task)

# 第一步：思考如何处理任务
act_1 = AgentAct(
    name=ThinkAct.action_name,
    params={INNER_ACT_KEY: f"""I can ask Confucius, Socrates and Aristotle one by one on their thoughts, and then summary the opinion myself."""
    },
)
obs_1 = "OK."

# 第二步：询问孔子的观点
act_2 = AgentAct(
    name=Confucius.name,
    params={AGENT_CALL_ARG_KEY: "What is your opinion on the meaning of life?",
        },
)
obs_2 = """Based on my thought, I think the meaning of life is to pursue value for the whold world."""

# 第三步：思考下一步行动
act_3 = AgentAct(
    name=ThinkAct.action_name,
    params={INNER_ACT_KEY: f"""I have obtained information from Confucius, I need to collect more information from Socrates."""
    },
)
obs_3 = "OK."

# 第四步：询问苏格拉底的观点
act_4 = AgentAct(
    name=Socrates.name,
    params={AGENT_CALL_ARG_KEY: "What is your opinion on the meaning of life?",
        },
)
obs_4 = """I think the meaning of life is finding happiness."""

# 第五步：继续思考下一步
act_5 = AgentAct(
    name=ThinkAct.action_name,
    params={INNER_ACT_KEY: f"""I have obtained information from Confucius and Socrates, I can collect more information from Aristotle."""
    },
)
obs_5 = "OK."

# 第六步：询问亚里士多德的观点
act_6 = AgentAct(
    name=Aristotle.name,
    params={AGENT_CALL_ARG_KEY: "What is your opinion on the meaning of life?",
        },
)
obs_6 = """I believe the freedom of spirit is the meaning."""

# 最后一步：总结所有观点
act_7 = AgentAct(name=FinishAct.action_name, params={INNER_ACT_KEY: "Their thought on the meaning of life is to pursue value, happiniss and freedom of spirit."})
obs_7 = "Task Completed. The meaning of life is to pursue value, happiness and freedom of spirit."

# 将所有动作和观察组合成序列
exp_act_obs = [(act_1, obs_1), (act_2, obs_2), (act_3, obs_3), (act_4, obs_4), (act_5, obs_5), (act_6, obs_6), (act_7, obs_7)]

# 将示例添加到管理者代理的提示生成器中
manager_agent.prompt_gen.add_example(
    task = exp_task_pack, action_chain = exp_act_obs
)

# %%
from zigent.commons import AgentAct, TaskPackage

exp_task = "先有鸡还是先有蛋?"
exp_task_pack = TaskPackage(instruction=exp_task)
manager_agent(exp_task_pack)
# Out:
# Agent manager_agent receives the following TaskPackage:
# [
# 	Task ID: 1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964
# 	Instruction: 先有鸡还是先有蛋?
# ]
# ====manager_agent starts execution on TaskPackage 1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964====
# Agent manager_agent takes 0-step Action:
# {
# 	name: Think
# 	params: {'response': 'To discuss the question of whether the chicken or the egg came first, I will ask Confucius, Socrates, and Aristotle, each of whom had different perspectives on knowledge and creation.'}
# }
# Observation: OK
# Agent manager_agent takes 1-step Action:
# {
# 	name: Confucius
# 	params: {'Task': 'What is your opinion on the question of whether the chicken or the egg came first?'}
# }
# Agent Confucius receives the following TaskPackage:
# [
# 	Task ID: 1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964
# 	Instruction: What is your opinion on the question of whether the chicken or the egg came first?
# ]
# ====Confucius starts execution on TaskPackage 1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964====
# Agent Confucius takes 0-step Action:
# {
# 	name: Think
# 	params: {'response': "As Confucius, I would consider this question from a metaphysical perspective. To me, the question of the chicken or the egg is not as important as the continuous cycle of creation and development. I believe that the universe, including the concept of life, operates through a process of interconnectedness and cyclical change. It is not a linear event but a cycle of cause and effect. Therefore, the question itself may not have a definitive answer in the traditional sense. It is more about understanding the nature of life's continuous existence and the interdependence of all things."}
# }
# Observation: OK
# Agent Confucius takes 1-step Action:
# {
# 	name: Finish
# 	params: {'response': 'In essence, I would say that the question of the chicken or the egg is more a philosophical inquiry than a factual one. It serves as a metaphor for understanding the interconnectedness of all things and the continuous cycle of life. As such, it is not about determining which came first, but rather about appreciating the ongoing process of creation and development in the universe.'}
# }
# Observation: In essence, I would say that the question of the chicken or the egg is more a philosophical inquiry than a factual one. It serves as a metaphor for understanding the interconnectedness of all things and the continuous cycle of life. As such, it is not about determining which came first, but rather about appreciating the ongoing process of creation and development in the universe.
# =========Confucius finish execution. TaskPackage[ID:1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964] status:
# [
# 	completion: completed
# 	answer: In essence, I would say that the question of the chicken or the egg is more a philosophical inquiry than a factual one. It serves as a metaphor for understanding the interconnectedness of all things and the continuous cycle of life. As such, it is not about determining which came first, but rather about appreciating the ongoing process of creation and development in the universe.
# ]
# ==========
# Observation: In essence, I would say that the question of the chicken or the egg is more a philosophical inquiry than a factual one. It serves as a metaphor for understanding the interconnectedness of all things and the continuous cycle of life. As such, it is not about determining which came first, but rather about appreciating the ongoing process of creation and development in the universe.
# Agent manager_agent takes 2-step Action:
# {
# 	name: Socrates
# 	params: {'Task': 'What is your opinion on the question of whether the chicken or the egg came first?'}
# }
# Agent Socrates receives the following TaskPackage:
# [
# 	Task ID: 1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964
# 	Instruction: What is your opinion on the question of whether the chicken or the egg came first?
# ]
# ====Socrates starts execution on TaskPackage 1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964====
# Agent Socrates takes 0-step Action:
# {
# 	name: Think
# 	params: {'response': "In addressing the question of whether the chicken or the egg came first, it's important to consider the nature of causality and the concept of time. From a Socratic perspective, the question itself suggests a linear progression of events, but the reality is that life and evolution do not adhere to such strict chronology. The chicken and the egg are interdependent; one cannot exist without the other. It seems more fitting to understand this as a cycle of development rather than a singular event. The egg might have laid the groundwork for the chicken, but the chicken also defines the subsequent eggs. Thus, the question, in its literal sense, may be unanswerable, for it is a product of the chicken-and-egg paradox, which highlights the interconnectedness of nature and the limitations of our understanding."}
# }
# Observation: OK
# Agent Socrates takes 1-step Action:
# {
# 	name: Finish
# 	params: {'response': 'In conclusion, as Socrates might suggest, the question of the chicken or the egg is not about a simple chronological event but rather about the intricate web of cause and effect in nature. It underscores the idea that life is a continuous cycle of interdependence and development, rather than a sequence of isolated events.'}
# }
# Observation: In conclusion, as Socrates might suggest, the question of the chicken or the egg is not about a simple chronological event but rather about the intricate web of cause and effect in nature. It underscores the idea that life is a continuous cycle of interdependence and development, rather than a sequence of isolated events.
# =========Socrates finish execution. TaskPackage[ID:1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964] status:
# [
# 	completion: completed
# 	answer: In conclusion, as Socrates might suggest, the question of the chicken or the egg is not about a simple chronological event but rather about the intricate web of cause and effect in nature. It underscores the idea that life is a continuous cycle of interdependence and development, rather than a sequence of isolated events.
# ]
# ==========
# Observation: In conclusion, as Socrates might suggest, the question of the chicken or the egg is not about a simple chronological event but rather about the intricate web of cause and effect in nature. It underscores the idea that life is a continuous cycle of interdependence and development, rather than a sequence of isolated events.
# Agent manager_agent takes 3-step Action:
# {
# 	name: Aristotle
# 	params: {'Task': 'What is your opinion on the question of whether the chicken or the egg came first?'}
# }
# Agent Aristotle receives the following TaskPackage:
# [
# 	Task ID: 1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964
# 	Instruction: What is your opinion on the question of whether the chicken or the egg came first?
# ]
# ====Aristotle starts execution on TaskPackage 1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964====
# Agent Aristotle takes 0-step Action:
# {
# 	name: Think
# 	params: {'response': 'In considering the question of whether the chicken or the egg came first, one must look to the natural order and the principles of causality. According to my understanding, every creature evolves from a previous form. Thus, the egg must have come first, as it is the tangible result of the genetic information that led to the development of the chicken. The chicken could not have existed before the egg, which contained the blueprint for its creation.'}
# }
# Observation: OK
# Agent Aristotle takes 1-step Action:
# {
# 	name: Finish
# 	params: {'response': 'Therefore, based on the natural progression of life and the principles of causality, it is my opinion that the egg came before the chicken.'}
# }
# Observation: Therefore, based on the natural progression of life and the principles of causality, it is my opinion that the egg came before the chicken.
# =========Aristotle finish execution. TaskPackage[ID:1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964] status:
# [
# 	completion: completed
# 	answer: Therefore, based on the natural progression of life and the principles of causality, it is my opinion that the egg came before the chicken.
# ]
# ==========
# Observation: Therefore, based on the natural progression of life and the principles of causality, it is my opinion that the egg came before the chicken.
# Agent manager_agent takes 4-step Action:
# {
# 	name: Finish
# 	params: {'response': 'Confucius views the question as a metaphor for understanding interconnectedness and the cycle of life, Socrates sees it as a reflection of the continuous cycle of interdependence and development, and Aristotle believes the egg came before the chicken due to the natural progression of life and principles of causality.'}
# }
# Observation: Confucius views the question as a metaphor for understanding interconnectedness and the cycle of life, Socrates sees it as a reflection of the continuous cycle of interdependence and development, and Aristotle believes the egg came before the chicken due to the natural progression of life and principles of causality.
# =========manager_agent finish execution. TaskPackage[ID:1d0a5cb3-3b59-4c2c-9ffa-e6aef5059964] status:
# [
# 	completion: completed
# 	answer: Confucius views the question as a metaphor for understanding interconnectedness and the cycle of life, Socrates sees it as a reflection of the continuous cycle of interdependence and development, and Aristotle believes the egg came before the chicken due to the natural progression of life and principles of causality.
# ]
# ==========
# 'Confucius views the question as a metaphor for understanding interconnectedness and the cycle of life, Socrates sees it as a reflection of the continuous cycle of interdependence and development, and Aristotle believes the egg came before the chicken due to the natural progression of life and principles of causality.'
